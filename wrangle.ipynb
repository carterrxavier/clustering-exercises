# %%
import wrangle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = wrangle.get_mall_customers()

# %%
wrangle.summerize_df(df)
# Out:
# -----Head-------
#    customer_id  gender  age  annual_income  spending_score
# 0            1    Male   19             15              39
# 1            2    Male   21             15              81
# 2            3  Female   20             16               6
# -----shape------
# 200 rows and 5 columns
# ---info---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     200 non-null    int64
#  1   gender          200 non-null    object
#  2   age             200 non-null    int64
#  3   annual_income   200 non-null    int64
#  4   spending_score  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB
# None
#        customer_id         age  annual_income  spending_score
# count   200.000000  200.000000     200.000000      200.000000
# mean    100.500000   38.850000      60.560000       50.200000
# ...

# %%
zillow_df = wrangle.get_all_zillow_data()
# Out:
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3357: DtypeWarning: Columns (63) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
zillow_df[:5]
# Out:
#    typeconstructiontypeid  storytypeid  propertylandusetypeid  \
# 0                     NaN          NaN                  261.0
# 1                     NaN          NaN                  261.0
# 2                     NaN          NaN                  261.0
# 3                     NaN          NaN                  261.0
# 4                     NaN          NaN                  266.0
#
#    heatingorsystemtypeid  buildingclasstypeid  architecturalstyletypeid  \
# 0                    NaN                  NaN                       NaN
# 1                    NaN                  NaN                       NaN
# 2                    NaN                  NaN                       NaN
# 3                    2.0                  NaN                       NaN
# 4                    2.0                  NaN                       NaN
#
#    airconditioningtypeid  parcelid       id  basementsqft  ...  \
# 0                    NaN  14297519  1727539           NaN  ...
# ...

# %%
wrangle.summerize_df(zillow_df)
# Out:
# -----Head-------
#    typeconstructiontypeid  storytypeid  propertylandusetypeid  \
# 0                     NaN          NaN                  261.0
# 1                     NaN          NaN                  261.0
# 2                     NaN          NaN                  261.0
#
#    heatingorsystemtypeid  buildingclasstypeid  architecturalstyletypeid  \
# 0                    NaN                  NaN                       NaN
# 1                    NaN                  NaN                       NaN
# 2                    NaN                  NaN                       NaN
#
#    airconditioningtypeid  parcelid       id  basementsqft  ...  \
# 0                    NaN  14297519  1727539           NaN  ...
# 1                    NaN  17052889  1387261           NaN  ...
# 2                    NaN  14186244    11677           NaN  ...
#
#    censustractandblock  logerror  transactiondate  airconditioningdesc  \
# 0         6.059063e+13  0.025595       2017-01-01                  NaN
# ...

# %%
cols , rows = wrangle.get_nulls(zillow_df)
# Out:
# <class 'pandas.core.series.Series'>

# %%
cols
# Out:
#                         num_rows_missing  percent_rows_missing
# typeconstructiontypeid             77353             99.713825
# storytypeid                        77525             99.935546
# propertylandusetypeid                  0              0.000000
# heatingorsystemtypeid              28005             36.100548
# buildingclasstypeid                77560             99.980664
# ...                                  ...                   ...
# buildingclassdesc                  77560             99.980664
# heatingorsystemdesc                28005             36.100548
# propertylandusedesc                    0              0.000000
# storydesc                          77525             99.935546
# typeconstructiondesc               77353             99.713825
#
# [68 rows x 2 columns]

# %%
rows
# Out:
#    num_cols_missing percent_cols_missing  num_rows
# 0                23    33.82352941176471         2
# 1                24   35.294117647058826        13
# 2                25    36.76470588235294        24
# 3                26    38.23529411764706        65
# 4                27   39.705882352941174       316
# 5                28    41.17647058823529       457
# 6                29    42.64705882352941      5285
# 7                30    44.11764705882353      3465
# 8                31   45.588235294117645      9911
# 9                32    47.05882352941176     12606
# 10               33   48.529411764705884     14817
# 11               34                 50.0     13357
# 12               35   51.470588235294116      5163
# 13               36    52.94117647058824      5793
# 14               37    54.41176470588235      3630
# 15               38    55.88235294117647      1932
# 16               39    57.35294117647059       285
# ...

# %% [markdown]
# ### Prepare

# %%
for i in zillow_df:
    if i == 'bedroomcnt' or i =='bathroomcnt':
        zillow_df = wrangle.handle_outliers(zillow_df, i, .10, .65)

# %%
zillow_df.shape
# Out:
# (70034, 68)

# %%
zillow_df = wrangle.drop_nulls(zillow_df, 1, 98)
# Out:
# <class 'pandas.core.series.Series'>

# %%
zillow_df.shape
# Out:
# (70034, 50)

# %%
rows = wrangle.get_nulls(zillow_df)[1]
for i in zillow_df.columns:
    for j in len(zillow_df):
        print(j)
# Out:
# <class 'pandas.core.series.Series'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-4ab2abdff4e3> in <module>
#       1 rows = wrangle.get_nulls(zillow_df)[1]
#       2 for i in zillow_df.columns:
# ----> 3     for j in len(zillow_df):
#       4         print(j)
#       5
#
# TypeError: 'int' object is not iterable

# %%
for i in zillow_df:
    print(i)
# Out:
# propertylandusetypeid
# heatingorsystemtypeid
# airconditioningtypeid
# parcelid
# id
# bathroomcnt
# bedroomcnt
# buildingqualitytypeid
# calculatedbathnbr
# finishedfloor1squarefeet
# calculatedfinishedsquarefeet
# finishedsquarefeet12
# finishedsquarefeet15
# finishedsquarefeet50
# fips
# fireplacecnt
# fullbathcnt
# garagecarcnt
# garagetotalsqft
# latitude
# longitude
# lotsizesquarefeet
# poolcnt
# pooltypeid7
# propertycountylandusecode
# propertyzoningdesc
# rawcensustractandblock
# regionidcity
# regionidcounty
# regionidneighborhood
# regionidzip
# roomcnt
# threequarterbathnbr
# unitcnt
# yardbuildingsqft17
# yearbuilt
# numberofstories
# structuretaxvaluedollarcnt
# taxvaluedollarcnt
# assessmentyear
# landtaxvaluedollarcnt
# taxamount
# taxdelinquencyflag
# taxdelinquencyyear
# censustractandblock
# logerror
# transactiondate
# airconditioningdesc
# heatingorsystemdesc
# propertylandusedesc
