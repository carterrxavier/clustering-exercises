# %%
import wrangle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = wrangle.get_mall_customers()

# %%
wrangle.summerize_df(df)
# Out:
# -----Head-------
#    customer_id  gender  age  annual_income  spending_score
# 0            1    Male   19             15              39
# 1            2    Male   21             15              81
# 2            3  Female   20             16               6
# -----shape------
# 200 rows and 5 columns
# ---info---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     200 non-null    int64
#  1   gender          200 non-null    object
#  2   age             200 non-null    int64
#  3   annual_income   200 non-null    int64
#  4   spending_score  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB
# None
#        customer_id         age  annual_income  spending_score
# count   200.000000  200.000000     200.000000      200.000000
# mean    100.500000   38.850000      60.560000       50.200000
# ...

# %%
zillow_df = wrangle.get_all_zillow_data()
# Out:
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3357: DtypeWarning: Columns (67) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
zillow_df[:5]
# Out:
#    typeconstructiontypeid  storytypeid  propertylandusetypeid  \
# 0                     NaN          NaN                  261.0
# 1                     NaN          NaN                  261.0
# 2                     NaN          NaN                  261.0
# 3                     NaN          NaN                  261.0
# 4                     NaN          NaN                  266.0
#
#    heatingorsystemtypeid  buildingclasstypeid  architecturalstyletypeid  \
# 0                    NaN                  NaN                       NaN
# 1                    NaN                  NaN                       NaN
# 2                    NaN                  NaN                       NaN
# 3                    2.0                  NaN                       NaN
# 4                    2.0                  NaN                       NaN
#
#    airconditioningtypeid  parcelid       id  basementsqft  ...  parcelid.1  \
# 0                    NaN  14297519  1727539           NaN  ...    14297519
# ...

# %%
wrangle.summerize_df(zillow_df)
# Out:
# -----Head-------
#    typeconstructiontypeid  storytypeid  propertylandusetypeid  \
# 0                     NaN          NaN                  261.0
# 1                     NaN          NaN                  261.0
# 2                     NaN          NaN                  261.0
#
#    heatingorsystemtypeid  buildingclasstypeid  architecturalstyletypeid  \
# 0                    NaN                  NaN                       NaN
# 1                    NaN                  NaN                       NaN
# 2                    NaN                  NaN                       NaN
#
#    airconditioningtypeid  parcelid       id  basementsqft  ...  parcelid.1  \
# 0                    NaN  14297519  1727539           NaN  ...    14297519
# 1                    NaN  17052889  1387261           NaN  ...    17052889
# 2                    NaN  14186244    11677           NaN  ...    14186244
#
#    logerror.1  transactiondate.1  airconditioningdesc  architecturalstyledesc  \
# ...

# %%
cols , rows = wrangle.get_nulls(zillow_df)
# Out:
# <class 'pandas.core.series.Series'>

# %%
cols
# Out:
#                         num_rows_missing  percent_rows_missing
# typeconstructiontypeid             77751             99.714007
# storytypeid                        77924             99.935876
# propertylandusetypeid                  0              0.000000
# heatingorsystemtypeid              28137             36.085105
# buildingclasstypeid                77959             99.980763
# ...                                  ...                   ...
# buildingclassdesc                  77959             99.980763
# heatingorsystemdesc                28137             36.085105
# propertylandusedesc                    0              0.000000
# storydesc                          77924             99.935876
# typeconstructiondesc               77751             99.714007
#
# [72 rows x 2 columns]

# %%
rows
# Out:
#    num_cols_missing percent_cols_missing  num_rows
# 0                23   31.944444444444443         2
# 1                24    33.33333333333333        13
# 2                25    34.72222222222222        24
# 3                26    36.11111111111111        66
# 4                27                 37.5       316
# 5                28    38.88888888888889       461
# 6                29    40.27777777777778      5315
# 7                30    41.66666666666667      3485
# 8                31    43.05555555555556      9951
# 9                32    44.44444444444444     12660
# 10               33    45.83333333333333     14889
# 11               34    47.22222222222222     13421
# 12               35    48.61111111111111      5195
# 13               36                 50.0      5829
# 14               37   51.388888888888886      3650
# 15               38    52.77777777777778      1946
# 16               39   54.166666666666664       285
# ...

# %% [markdown]
# ### Prepare

# %%
zillow_df =wrangle.get_all_zillow_data()
# Out:
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3357: DtypeWarning: Columns (67) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
zillow_df.shape
# Out:
# (77974, 72)

# %%
#removing the outliers for bathroom cnt and bedroom count is a way to limit house size by room count
for i in zillow_df:
    if i == 'bedroomcnt' or i =='bathroomcnt':
        zillow_df = wrangle.handle_outliers(zillow_df, i, .10, .65)

# %%
zillow_df.shape
# Out:
# (70391, 72)

# %%
#drop column if its missing 50% or more of its rows
zillow_df = wrangle.drop_nulls(zillow_df, 1, 50)
# Out:
# <class 'pandas.core.series.Series'>

# %%
zillow_df.shape
# Out:
# (70391, 38)

# %%
#drop row if its missing 20% or more of its columns
zillow_df = wrangle.drop_nulls(zillow_df,0, 20)

# %%
zillow_df.shape
# Out:
# (70356, 38)

# %%
zillow_df.head(5)
# Out:
#    propertylandusetypeid  heatingorsystemtypeid  parcelid       id  \
# 0                  261.0                    NaN  14297519  1727539
# 1                  261.0                    NaN  17052889  1387261
# 2                  261.0                    NaN  14186244    11677
# 3                  261.0                    2.0  12177905  2288172
# 4                  266.0                    2.0  10887214  1970746
#
#    bathroomcnt  bedroomcnt  buildingqualitytypeid  calculatedbathnbr  \
# 0          3.5         4.0                    NaN                3.5
# 1          1.0         2.0                    NaN                1.0
# 2          2.0         3.0                    NaN                2.0
# 3          3.0         4.0                    8.0                3.0
# 4          3.0         3.0                    8.0                3.0
#
#    calculatedfinishedsquarefeet  finishedsquarefeet12  ...  taxamount  \
# 0                        3100.0                3100.0  ...   11013.72
# ...

# %%
zillow_df.propertylandusedesc.value_counts()
# Out:
# Single Family Residential                     47251
# Condominium                                   19105
# Planned Unit Development                       1767
# Duplex (2 Units, Any Combination)              1360
# Cluster Home                                    339
# Triplex (3 Units, Any Combination)              220
# Quadruplex (4 Units, Any Combination)           180
# Mobile Home                                      59
# Manufactured, Modular, Prefabricated Homes       35
# Cooperative                                      29
# Townhouse                                         6
# Residential General                               5
# Name: propertylandusedesc, dtype: int64

# %%
zillow_df.isna().sum()
# Out:
# propertylandusetypeid               0
# heatingorsystemtypeid           24476
# parcelid                            0
# id                                  0
# bathroomcnt                         0
# bedroomcnt                          0
# buildingqualitytypeid           24873
# calculatedbathnbr                   1
# calculatedfinishedsquarefeet        3
# finishedsquarefeet12             1929
# fips                                0
# fullbathcnt                         1
# latitude                            0
# longitude                           0
# lotsizesquarefeet                8064
# propertycountylandusecode           0
# propertyzoningdesc              24517
# rawcensustractandblock              0
# regionidcity                     1228
# regionidcounty                      0
# regionidzip                        27
# roomcnt                             0
# unitcnt                         24475
# yearbuilt                          40
# structuretaxvaluedollarcnt         81
# ...

# %%
zillow_df = zillow_df.dropna()

# %%
zillow_df.isna().sum()
# Out:
# propertylandusetypeid           0
# heatingorsystemtypeid           0
# parcelid                        0
# id                              0
# bathroomcnt                     0
# bedroomcnt                      0
# buildingqualitytypeid           0
# calculatedbathnbr               0
# calculatedfinishedsquarefeet    0
# finishedsquarefeet12            0
# fips                            0
# fullbathcnt                     0
# latitude                        0
# longitude                       0
# lotsizesquarefeet               0
# propertycountylandusecode       0
# propertyzoningdesc              0
# rawcensustractandblock          0
# regionidcity                    0
# regionidcounty                  0
# regionidzip                     0
# roomcnt                         0
# unitcnt                         0
# yearbuilt                       0
# structuretaxvaluedollarcnt      0
# taxvaluedollarcnt               0
# assessmentyear                  0
# ...

# %%
zillow_df.parcelid.value_counts()
# Out:
# 13083743    6
# 12535098    4
# 11705026    4
# 12224279    4
# 10739478    4
#            ..
# 11199798    1
# 12643639    1
# 10786104    1
# 11226556    1
# 11499454    1
# Name: parcelid, Length: 40725, dtype: int64

# %% [markdown]
# ###
